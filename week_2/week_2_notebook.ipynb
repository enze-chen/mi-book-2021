# %% [markdown]
# # Week 2 Jupyter notebook placeholder

# %%
import os
import sys
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Exercise 1: Print `'Hello, World!`

# %%
print('Hello, World!')
